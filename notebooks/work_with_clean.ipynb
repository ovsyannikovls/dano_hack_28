# %%
import pandas as pd

df = pd.read_excel("../data/clean_base.xlsx")

# %%
print(df['business_trips'].value_counts(normalize=True) * 100)
print(df['inactive'].value_counts(normalize=True) * 100)
print(df['relocation'].value_counts(normalize=True) * 100)
print(df['retraining_capability'].value_counts(normalize=True) * 100)
df = df['schedule_type'].value_counts(normalize=True) * 100
print(df.head())
# Out:
# business_trips
# 0.0    94.255796
# 1.0     5.744204
# Name: proportion, dtype: float64
# inactive
# 1    96.789936
# 0     3.210064
# Name: proportion, dtype: float64
# relocation
# 0.0    98.980793
# 1.0     1.019207
# Name: proportion, dtype: float64
# retraining_capability
# 1.0    99.308131
# 0.0     0.691869
# Name: proportion, dtype: float64
# schedule_type
# Полный рабочий день                                 78.081562
# Полный рабочий день,Сменный график                   5.300106
# Сменный график                                       3.394068
# Неполный рабочий день                                1.636033
# Гибкий график,Полный рабочий день,Сменный график     1.406028
# Name: proportion, dtype: float64
