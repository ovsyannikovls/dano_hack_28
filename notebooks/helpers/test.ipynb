# %%
import pandas as pd

df = pd.read_excel("../../data/processed/v1_clean_base.xlsx")

print(df["region_code"].unique())
# Out:
# [50 23 74 28 61 63 46 20 42  2 22 59 78 37 64 89 45 39 36 76 19 24 35  1
#  77 34 18 86 66 21 54 16 91 51 48 67 44 43 33 72 83 10 25 71 30 58 14 31
#  38 52 55 13 26 40 68 56 41 53  3 69 60 62 75 15  7  6 70 27 47  4  9  8
#  65 29 32 12 11 73 57  5 79 92 49 17 87]
